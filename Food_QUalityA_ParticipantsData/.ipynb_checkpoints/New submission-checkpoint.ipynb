# %%
import numpy as np
import pandas as pd
import re
#import xgboost as xgb
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#import plotly.offline as py
#py.init_notebook_mode(connected=True)
#import plotly.graph_objs as go
#import plotly.tools as tls

from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from IPython.display import Image as PImage
from subprocess import check_call
from PIL import Image, ImageDraw, ImageFont
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
# %matplotlib inline 
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from collections import Counter

# %%
zf = pd.read_excel('/home/ryan/MachineHack/Food_QUalityA_ParticipantsData/Data_Train.xlsx')

# %%
zf['LicenseNo'].duplicated().any()
# Out:
# True

# %%
cols_to_drop = [
    'Date',
    'ID'
    ]

zf = zf.drop(cols_to_drop, axis=1)

# %%
zf.head(3)
# Out:
#    LicenseNo  FacilityID  FacilityName           Type  Street         City  \
# 0       4744        8123          7715     RESTAURANT   15522  id-11235901
# 1       2973       12268         11664  GROCERY STORE    3057  id-11235901
# 2      18223        1112           969     RESTAURANT   14988  id-11235901
#
#         State  LocationID     Reason  SectionViolations RiskLevel     Geo_Loc  \
# 0  id_1890134     81876.0    CANVASS               33.0      High  locid16406
# 1  id_1890134     81862.0  COMPLAINT               33.0      High    locid878
# 2  id_1890134     81883.0    CANVASS                NaN      High   locid3368
#
#    Inspection_Results
# 0                   4
# 1                   4
# 2                   6

# %%
total = zf.isnull().sum().sort_values(ascending=False)
percent_1 = zf.isnull().sum()/zf.isnull().count()*100
percent_2 = (np.round(percent_1, 1)).sort_values(ascending=False)
missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%']) #ptr
missing_data
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.
#                     Total     %
# City                    0   0.0
# FacilityID              0   0.0
# FacilityName            0   0.0
# Geo_Loc                 0   0.0
# Inspection_Results      0   0.0
# LicenseNo               0   0.0
# LocationID             35   0.0
# Reason                  0   0.0
# RiskLevel               0   0.0
# SectionViolations   39068  26.5
# State                   0   0.0
# Street                  0   0.0
# Type                 3485   2.4

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(strategy='most_frequent')
df = imp.fit_transform(zf)

# %%
# Out:
# array([[4744, 8123, 7715, ..., 'High', 'locid16406', 4],
#        [2973, 12268, 11664, ..., 'High', 'locid878', 4],
#        [18223, 1112, 969, ..., 'High', 'locid3368', 6],
#        ...,
#        [5361, 12685, 12038, ..., 'Medium', 'locid3614', 6],
#        [12338, 10898, 10324, ..., 'High', 'locid757', 5],
#        [18743, 1392, 1249, ..., 'High', 'locid16090', 4]], dtype=object)

# %%
dataframe = pd.DataFrame.from_records(df)

# %%
dataframe.head(3)
# Out:
#        0      1      2              3      4            5           6  \
# 0   4744   8123   7715     RESTAURANT  15522  id-11235901  id_1890134
# 1   2973  12268  11664  GROCERY STORE   3057  id-11235901  id_1890134
# 2  18223   1112    969     RESTAURANT  14988  id-11235901  id_1890134
#
#          7          8     9    10          11  12
# 0  81876.0    CANVASS  33.0  High  locid16406   4
# 1  81862.0  COMPLAINT  33.0  High    locid878   4
# 2  81883.0    CANVASS  32.0  High   locid3368   6

# %%
dataframe.rename(columns = { 0:'LicenseNo',1:'FacilityID',2:'FacilityName', 3:'Type',4:'Street',5:'City',6:'State',7:'LocationID',8:'Reason',9:'SectionViolations',10:'RiskLevel',11:'Geo_Loc',12:'Inspection_Results'},inplace=True)

# %%
dataframe.head(2)
# Out:
#    LicenseNo  FacilityID  FacilityName           Type  Street         City  \
# 0       4744        8123          7715     RESTAURANT   15522  id-11235901
# 1       2973       12268         11664  GROCERY STORE    3057  id-11235901
#
#         State  LocationID     Reason  SectionViolations RiskLevel     Geo_Loc  \
# 0  id_1890134     81876.0    CANVASS               33.0      High  locid16406
# 1  id_1890134     81862.0  COMPLAINT               33.0      High    locid878
#
#    Inspection_Results
# 0                   4
# 1                   4

# %%
dataframe = pd.get_dummies(dataframe, prefix="RiskLevel",columns=['RiskLevel'])
dataframe = pd.get_dummies(dataframe, prefix="City",columns=['City'])
dataframe = pd.get_dummies(dataframe, prefix="State",columns=['State'])
dataframe = pd.get_dummies(dataframe, prefix="Reason",columns=['Reason'])

# %%
dataframe.head(3)
# Out:
#    LicenseNo  FacilityID  FacilityName           Type  Street  LocationID  \
# 0       4744        8123          7715     RESTAURANT   15522     81876.0
# 1       2973       12268         11664  GROCERY STORE    3057     81862.0
# 2      18223        1112           969     RESTAURANT   14988     81883.0
#
#    SectionViolations     Geo_Loc  Inspection_Results  RiskLevel_High  ...  \
# 0               33.0  locid16406                   4               1  ...
# 1               33.0    locid878                   4               1  ...
# 2               32.0   locid3368                   6               1  ...
#
#    Reason_LICENSE RE-INSPECTION  Reason_LICENSE-TASK FORCE  \
# 0                             0                          0
# 1                             0                          0
# 2                             0                          0
#
#    Reason_OUT OF BUSINESS  Reason_RECENT INSPECTION  \
# 0                       0                         0
# 1                       0                         0
# 2                       0                         0
#
#    Reason_SHORT FORM COMPLAINT  Reason_SHORT FORM FIRE-COMPLAINT  \
# 0                            0                                 0
# 1                            0                                 0
# 2                            0                                 0
#
#    Reason_SUSPECTED FOOD POISONING  \
# 0                                0
# 1                                0
# 2                                0
#
#    Reason_SUSPECTED FOOD POISONING RE-INSPECTION  Reason_TAG REMOVAL  \
# 0                                              0                   0
# 1                                              0                   0
# 2                                              0                   0
#
#    Reason_TASK FORCE LIQUOR 1475
# 0                              0
# 1                              0
# 2                              0
#
# [3 rows x 34 columns]

# %%
from sklearn import preprocessing 
  
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
dataframe['Type']= label_encoder.fit_transform(dataframe['Type']) 
dataframe['Geo_Loc'] = label_encoder.fit_transform(dataframe['Geo_Loc'])
dataframe['FacilityID'] = label_encoder.fit_transform(dataframe['FacilityID'])
dataframe['FacilityName'] = label_encoder.fit_transform(dataframe['FacilityName'])
dataframe['LocationID'] = label_encoder.fit_transform(dataframe['LocationID'])
dataframe['SectionViolations'] = label_encoder.fit_transform(dataframe['SectionViolations'])
dataframe['LicenseNo'] = label_encoder.fit_transform(dataframe['LicenseNo'])

# %%
dataframe.head(3)
# Out:
#    LicenseNo  FacilityID  FacilityName  Type  Street  LocationID  \
# 0       4203        7549          7157   326   15522          69
# 1       2635       11435         10865   182    3057          55
# 2      16649        1023           879   326   14988          75
#
#    SectionViolations  Geo_Loc  Inspection_Results  RiskLevel_High  ...  \
# 0                 32     6889                   4               1  ...
# 1                 32    14998                   4               1  ...
# 2                 31     9140                   6               1  ...
#
#    Reason_LICENSE RE-INSPECTION  Reason_LICENSE-TASK FORCE  \
# 0                             0                          0
# 1                             0                          0
# 2                             0                          0
#
#    Reason_OUT OF BUSINESS  Reason_RECENT INSPECTION  \
# 0                       0                         0
# 1                       0                         0
# 2                       0                         0
#
#    Reason_SHORT FORM COMPLAINT  Reason_SHORT FORM FIRE-COMPLAINT  \
# 0                            0                                 0
# 1                            0                                 0
# 2                            0                                 0
#
#    Reason_SUSPECTED FOOD POISONING  \
# 0                                0
# 1                                0
# 2                                0
#
#    Reason_SUSPECTED FOOD POISONING RE-INSPECTION  Reason_TAG REMOVAL  \
# 0                                              0                   0
# 1                                              0                   0
# 2                                              0                   0
#
#    Reason_TASK FORCE LIQUOR 1475
# 0                              0
# 1                              0
# 2                              0
#
# [3 rows x 34 columns]

# %%
plt.figure()
sns.heatmap(dataframe.corr())

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147443 entries, 0 to 147442
# Data columns (total 34 columns):
# LicenseNo                                        147443 non-null int64
# FacilityID                                       147443 non-null int64
# FacilityName                                     147443 non-null int64
# Type                                             147443 non-null int64
# Street                                           147443 non-null int64
# LocationID                                       147443 non-null int64
# SectionViolations                                147443 non-null int64
# Geo_Loc                                          147443 non-null int64
# Inspection_Results                               147443 non-null int64
# RiskLevel_High                                   147443 non-null uint8
# RiskLevel_Low                                    147443 non-null uint8
# RiskLevel_Medium                                 147443 non-null uint8
# RiskLevel_Uncertain                              147443 non-null uint8
# City_id-11235901                                 147443 non-null uint8
# City_id-11275913                                 147443 non-null uint8
# State_id_1890134                                 147443 non-null uint8
# State_id_1890135                                 147443 non-null uint8
# Reason_CANVASS                                   147443 non-null uint8
# Reason_CANVASS RE-INSPECTION                     147443 non-null uint8
# Reason_COMPLAINT                                 147443 non-null uint8
# Reason_COMPLAINT RE-INSPECTION                   147443 non-null uint8
# Reason_COMPLAINT-FIRE                            147443 non-null uint8
# Reason_CONSULTATION                              147443 non-null uint8
# Reason_LICENSE                                   147443 non-null uint8
# Reason_LICENSE RE-INSPECTION                     147443 non-null uint8
# Reason_LICENSE-TASK FORCE                        147443 non-null uint8
# Reason_OUT OF BUSINESS                           147443 non-null uint8
# Reason_RECENT INSPECTION                         147443 non-null uint8
# Reason_SHORT FORM COMPLAINT                      147443 non-null uint8
# Reason_SHORT FORM FIRE-COMPLAINT                 147443 non-null uint8
# Reason_SUSPECTED FOOD POISONING                  147443 non-null uint8
# Reason_SUSPECTED FOOD POISONING RE-INSPECTION    147443 non-null uint8
# Reason_TAG REMOVAL                               147443 non-null uint8
# Reason_TASK FORCE LIQUOR 1475                    147443 non-null uint8
# dtypes: int64(9), uint8(25)
# memory usage: 13.6 MB

# %%
dataframe.describe()
# Out:
#            LicenseNo     FacilityID   FacilityName           Type  \
# count  147443.000000  147443.000000  147443.000000  147443.000000
# mean    16232.659896   13091.831867   12477.808577     288.521680
# std     10085.889177    7298.512505    6934.495338      78.589235
# min         0.000000       0.000000       0.000000       0.000000
# 25%      7645.000000    6828.000000    6487.000000     326.000000
# 50%     15548.000000   13307.000000   12784.000000     326.000000
# 75%     24186.000000   19475.000000   18480.000000     326.000000
# max     34383.000000   25534.000000   24347.000000     408.000000
#
#               Street     LocationID  SectionViolations        Geo_Loc  \
# count  147443.000000  147443.000000      147443.000000  147443.000000
# mean     8684.119653      66.173966          25.203584    8458.032514
# std      5255.991577      16.643459          11.369530    4733.932657
# min         0.000000       0.000000           0.000000       0.000000
# 25%      4109.000000      52.000000          17.000000    4411.000000
# 50%      8541.000000      63.000000          31.000000    8549.000000
# 75%     13321.000000      80.000000          31.000000   12796.000000
# max     17891.000000     103.000000          60.000000   16315.000000
#
#        Inspection_Results  RiskLevel_High  ...  Reason_LICENSE RE-INSPECTION  \
# count       147443.000000   147443.000000  ...                 147443.000000
# mean             3.680405        0.717470  ...                      0.046092
# std              1.481441        0.450231  ...                      0.209686
# min              0.000000        0.000000  ...                      0.000000
# 25%              4.000000        0.000000  ...                      0.000000
# 50%              4.000000        1.000000  ...                      0.000000
# 75%              4.000000        1.000000  ...                      0.000000
# max              6.000000        1.000000  ...                      1.000000
#
#        Reason_LICENSE-TASK FORCE  Reason_OUT OF BUSINESS  \
# count              147443.000000           147443.000000
# mean                    0.003011                0.001492
# std                     0.054793                0.038599
# min                     0.000000                0.000000
# 25%                     0.000000                0.000000
# 50%                     0.000000                0.000000
# 75%                     0.000000                0.000000
# max                     1.000000                1.000000
#
#        Reason_RECENT INSPECTION  Reason_SHORT FORM COMPLAINT  \
# count             147443.000000                147443.000000
# mean                   0.001682                     0.034549
# std                    0.040978                     0.182635
# min                    0.000000                     0.000000
# 25%                    0.000000                     0.000000
# 50%                    0.000000                     0.000000
# 75%                    0.000000                     0.000000
# max                    1.000000                     1.000000
#
#        Reason_SHORT FORM FIRE-COMPLAINT  Reason_SUSPECTED FOOD POISONING  \
# count                     147443.000000                    147443.000000
# mean                           0.000522                         0.004280
# std                            0.022847                         0.065279
# min                            0.000000                         0.000000
# 25%                            0.000000                         0.000000
# 50%                            0.000000                         0.000000
# 75%                            0.000000                         0.000000
# max                            1.000000                         1.000000
#
#        Reason_SUSPECTED FOOD POISONING RE-INSPECTION  Reason_TAG REMOVAL  \
# count                                  147443.000000       147443.000000
# mean                                        0.000997            0.003093
# std                                         0.031560            0.055526
# min                                         0.000000            0.000000
# 25%                                         0.000000            0.000000
# 50%                                         0.000000            0.000000
# 75%                                         0.000000            0.000000
# max                                         1.000000            1.000000
#
#        Reason_TASK FORCE LIQUOR 1475
# count                  147443.000000
# mean                        0.001268
# std                         0.035591
# min                         0.000000
# 25%                         0.000000
# 50%                         0.000000
# 75%                         0.000000
# max                         1.000000
#
# [8 rows x 34 columns]

# %%
Y = dataframe['Inspection_Results']
X = dataframe.drop('Inspection_Results', axis =1)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
print(len(X_train))
print(len(Y_train))
print(len(X_test))
print(len(X_test))
# Out:
# 103210
# 103210
# 44233
# 44233

# %%
print(sorted(Counter(Y_train).items()))
# Out:
# [(0, 30), (1, 19893), (2, 1011), (3, 3278), (4, 55525), (5, 14572), (6, 8901)]

# %%
rus = RandomUnderSampler(random_state=0)
X_resampled, y_resampled = rus.fit_resample(X, y)
print(sorted(Counter(y_resampled).items()))

# %%
# dataframe.to_excel(excel_writer = "/home/ryan/MachineHack/Food_QUalityA_ParticipantsData/Data_TrainCLEANED.xlsx")
