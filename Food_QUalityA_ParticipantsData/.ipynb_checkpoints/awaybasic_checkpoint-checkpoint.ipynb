# %%
import pandas as pd
import numpy as np
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import category_encoders
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
import xgboost as xgb
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from mlxtend.classifier import StackingClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import BaggingClassifier
import matplotlib as plt
from random import randint

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder



print("Setup Complete")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Setup Complete

# %%
# Read the file into a variable fifa_data
filepath = "/home/ryan/stark/MachineHack/Food_QUalityA_ParticipantsData/Data_Train.xlsx"
data = pd.read_excel(filepath)

# %%
submission= pd.read_excel('/home/ryan/stark/MachineHack/Food_QUalityA_ParticipantsData/Sample_Submission.xlsx')
# data.head(3)

# %%
from sklearn.model_selection import train_test_split
y = data.Inspection_Results

# To keep things simple, we'll use only numerical predictors
X = data.drop(['Inspection_Results'], axis=1)

X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.65, test_size=0.35,random_state=0)

# %%
X_train.skew()
# Out:
# ID                     0.007343
# LicenseNo              0.186462
# FacilityID            -0.064033
# FacilityName          -0.070667
# Street                 0.042701
# LocationID          -267.384769
# SectionViolations     -0.541301
# dtype: float64

# %%
X_valid.head()
# Out:
#                     ID        Date  LicenseNo  FacilityID  FacilityName  \
# 76851   24443412747647  09-07-2018      28225        4702          4480
# 36203   47254212658879  17-11-2014        743       25793         24635
# 3760    25946353205233  19-12-2015      24297       13257         12588
# 51377   28473392743625  21-10-2010      18030        7609          7234
# 116892  45067242875655  31-01-2012      17544       23678         22588
#
#               Type  Street         City       State  LocationID  \
# 76851   RESTAURANT   13072  id-11235901  id_1890134     81875.0
# 36203   CAFE/STORE    2087  id-11235901  id_1890134     81882.0
# 3760    RESTAURANT    2382  id-11235901  id_1890134     81855.0
# 51377       SCHOOL   12441  id-11235901  id_1890134     81883.0
# 116892  RESTAURANT     479  id-11235901  id_1890134     81862.0
#
#                        Reason  SectionViolations RiskLevel     Geo_Loc
# 76851                 CANVASS                2.0      High  locid15302
# 36203                 CANVASS               32.0    Medium   locid3211
# 3760    CANVASS RE-INSPECTION                NaN      High   locid9774
# 51377                 CANVASS               32.0      High   locid3875
# 116892                CANVASS               33.0      High    locid511

# %%
class LabelEncoderExt(object):
    def __init__(self):
        """
        It differs from LabelEncoder by handling new classes and providing a value for it [Unknown]
        Unknown will be added in fit and transform will take care of new item. It gives unknown class id
        """
        self.label_encoder = LabelEncoder()
        # self.classes_ = self.label_encoder.classes_

    def fit(self, data_list):
        """
        This will fit the encoder for all the unique values and introduce unknown value
        :param data_list: A list of string
        :return: self
        """
        self.label_encoder = self.label_encoder.fit(list(data_list) + ['Unknown'])
        self.classes_ = self.label_encoder.classes_

        return self

    def transform(self, data_list):
        """
        This will transform the data_list to id list where the new values get assigned to Unknown class
        :param data_list:
        :return:
        """
        new_data_list = list(data_list)
        for unique_item in np.unique(data_list):
            if unique_item not in self.label_encoder.classes_:
                new_data_list = ['Unknown' if x==unique_item else x for x in new_data_list]

        return self.label_encoder.transform(new_data_list)
    
    
    
    
    
# from sklearn.tree import DecisionTreeClassifier

# from sklearn.ensemble import BaggingClassifier

# clf1 = DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=11, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=8, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# clf2 = BaggingClassifier(base_estimator=clf1, n_estimators=100, max_samples=1.0, max_features=1.0, 
#                          bootstrap=True,
#                          bootstrap_features=False, oob_score=True, warm_start=False,
#                          n_jobs=-1, random_state=None, verbose=0)

# clf3=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, gamma=0.5,
#               learning_rate=0.1, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=0.6, verbosity=1)

# %%
def dropcol(train,test):
    train['logID'] = np.log1p(train['ID'])
    test['logID'] = np.log1p(test['ID'])
    cols_to_drop = ['Date','ID']
    dtrain = train.drop(cols_to_drop,axis =1)
    dtest = test.drop(cols_to_drop,axis =1)
    
    print(dtrain.shape,dtest.shape)

    return dtrain,dtest

def catVar1(data):
    categorical_colsT1 = [cname for cname in data.columns if
                    data[cname].nunique() <=10 and 
                    data[cname].dtype == "object"]
    return categorical_colsT1

def catVar2(data):
    categorical_colsT2 = [cname for cname in data.columns if
                    data[cname].nunique() >10 and 
                    data[cname].dtype == "object"]
    return categorical_colsT2

def NumVar(data) :
    numerical_cols = [cname for cname in data.columns if 
    data[cname].dtype in ['int64', 'float64']]
    return numerical_cols

def imputer(train,test):
    
    from sklearn.impute import SimpleImputer
    
    numerical_cols = NumVar(train)
    my_imputer = SimpleImputer(strategy='most_frequent')
    imputed_train = pd.DataFrame(my_imputer.fit_transform(train))
    imputed_test = pd.DataFrame(my_imputer.transform(test))

    # Imputation removed column names; put them back
    imputed_train.columns = train.columns
    imputed_test.columns = test.columns
    
    #restoring datatypes 
    imputed_train[numerical_cols] = imputed_train[numerical_cols].apply(pd.to_numeric, errors='coerce')
    imputed_test[numerical_cols] = imputed_test[numerical_cols].apply(pd.to_numeric, errors='coerce')
    print(imputed_train.shape,imputed_test.shape)
    return imputed_train,imputed_test 

def robustlabelencoder(train,test):
    from sklearn.preprocessing import LabelEncoder

    label_enc = LabelEncoderExt()
    cols = catVar2(train)
    print(cols)
    for col in cols:
        label_enc.fit(train[col])
        train[col] = label_enc.transform(train[col])
        test[col] = label_enc.transform(test[col])
        
    print(train.shape,test.shape)
    
    return train,test

def normalabelencoder(train,test,cols):
    from sklearn.preprocessing import LabelEncoder

    label_enc = LabelEncoder()
    
    print(cols)
    for col in cols:
        label_enc.fit(train[col])
        train[col] = label_enc.transform(train[col])
        test[col] = label_enc.transform(test[col])
    
    return train,test



def ohebygetdummis(train,test):
    pass

def onhotencoder(train,test):
    
    from sklearn.preprocessing import OneHotEncoder
    object_cols = catVar1(train) #catVar1 gives desired categorical column and not all object columns
    print(object_cols)
    
    OH_encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)
    OH_cols_train = pd.DataFrame(OH_encoder.fit_transform(train[object_cols]))
    OH_cols_test = pd.DataFrame(OH_encoder.transform(test[object_cols]))

    # One-hot encoding removed index; put it back
    OH_cols_train.index = train.index
    OH_cols_test.index = test.index

    ##hack for restoring columns names just like get dummies
    column_name = OH_encoder.get_feature_names(object_cols)
    OH_cols_train.columns = column_name
    OH_cols_test.columns = column_name
    

    # Remove desired categorical columns (will replace with one-hot encoding)
    num_train = train.drop(object_cols, axis=1)
    num_test = test.drop(object_cols, axis=1)

    # Add one-hot encoded columns to numerical/remaining features
    OH_train = pd.concat([num_train, OH_cols_train], axis=1)
    OH_test = pd.concat([num_test, OH_cols_test], axis=1)
    
    print(OH_train.shape,OH_test.shape)
    
    
    return OH_train,OH_test

def missingcheck(data):
    total = data.isnull().sum().sort_values(ascending=False)
    percent_1 = data.isnull().sum()/data.isnull().count()*100
    percent_2 = (np.round(percent_1, 1)).sort_values(ascending=False)
    missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%']) #ptr
    return missing_data

def targetencoding(train,test,y_train):
    import category_encoders as ce
    # Create the encoder itself
    cat_features = catVar2(train)
    print(f'targest emcoding for features {cat_features}')
    target_enc = ce.TargetEncoder(cols=cat_features)

    

    # Fit the encoder using the categorical features and target
    target_enc.fit(train[cat_features], y_train)
    

    # Transform the features, rename the columns with _target suffix, and join to dataframe
    traintrgtenc = train.join(target_enc.transform(train[cat_features]).add_suffix('_target'))
    testtrgtenc = test.join(target_enc.transform(test[cat_features]).add_suffix('_target'))

    traintrgtenc = traintrgtenc.drop(cat_features, axis =1)
    testtrgtenc = testtrgtenc.drop(cat_features, axis =1)

    
    print(traintrgtenc.shape,testtrgtenc.shape)
    
    return traintrgtenc,testtrgtenc


def special(train,test):
    train['Geo_Loc'] = train['Geo_Loc'].str.replace(r'\D', '')
    train['Geo_Loc'] = pd.to_numeric(train['Geo_Loc'], errors='coerce') 
    
    test['Geo_Loc'] = test['Geo_Loc'].str.replace(r'\D', '')
    test['Geo_Loc'] = pd.to_numeric(test['Geo_Loc'], errors='coerce')
    
    train['Date'] = pd.to_datetime(train['Date'] ,errors='coerce')
    test['Date'] = pd.to_datetime(test['Date'] ,errors='coerce')
    
    train = train.assign(
               hour=train.Date.dt.hour,
               day=train.Date.dt.day,
               month=train.Date.dt.month,
               year=train.Date.dt.year
                        )
    
    test = test.assign(
               hour=test.Date.dt.hour,
               day=test.Date.dt.day,
               month=test.Date.dt.month,
               year=test.Date.dt.year
                        )
    print(train.shape,test.shape)
    
    return train, test

# %%
# def syntheticvariable(train , y ):
#     from imblearn.over_sampling import SMOTENC
#     from collections import Counter
#     categorical_features = [cname.index for cname in train.columns if train[cname].dtype == "object"]
#     out = np.argwhere(train.columns.isin(categorical_features)).ravel().tolist()
    
#     smote_nc = SMOTENC([3, 5, 6, 8, 10], random_state=0)  #instead of passing out i need to hardcode it.

#     X_resampled, y_resampled = smote_nc.fit_resample(train,y)
    
#     print(sorted(Counter(y_resampled).items()))
    
#     return X_resampled,y_resampled

# %%
#####crete new features###

# %%
def createIntercations(train,test,cat_features):
    import itertools
    print(f"Creating features on {cat_features}, with combination 2 for training data /n")
    interactionstrain = pd.DataFrame(index=train.index)
    
    for col1 ,col2 in  itertools.combinations(cat_features,2):   
        newcolname = col1 + "_" + col2 
        new_values = train[col1].map(str) + "_" + train[col2].map(str)
        interactionstrain[newcolname] = new_values

    
    train_df = train.join(interactionstrain)
    
    print(f"Creating features on {cat_features}, with combination 2 for testing data")
    interactionstest = pd.DataFrame(index=train.index)
    
    for col1 ,col2 in  itertools.combinations(cat_features,2):   
        newcolname = col1 + "_" + col2 
        new_values = test[col1].map(str) + "_" + test[col2].map(str)
        interactionstest[newcolname] = new_values

    test_df = test.join(interactionstest)
    
    print(train_df.shape,test_df.shape)
    
    
    return train_df,test_df

# %%
def createmeanfestures(train,test ,features):
  
  cols = features
  interactionstrain = pd.DataFrame(index=train.index)
  interactionstest = pd.DataFrame(index=test.index)

  for col  in cols:   
        newcolname = col + "_mean"   
        new_values = train[col].mean()
        interactionstrain[newcolname] = new_values

  for col  in cols:   
        newcolname = col + "_mean"   
        new_values = test[col].mean()
        interactionstest[newcolname] = new_values


  train_df = train.join(interactionstrain)
  test_df = test.join(interactionstest)

  print(train_df.shape,test_df.shape)

  return train_df,test_df




def createlogfestures(train,test,features):
  
  cols = features
  interactionstrain = pd.DataFrame(index=train.index)
  interactionstest = pd.DataFrame(index=test.index)
  for col  in cols:   
        newcolname = col + "_log"   
        new_values = np.log1p(train[col])
        interactionstrain[newcolname] = new_values

  for col  in cols:   
        newcolname = col + "_log"   
        new_values = np.log1p(test[col])
        interactionstest[newcolname] = new_values


  train_df = train.join(interactionstrain)
  test_df = test.join(interactionstest)

  print(train_df.shape,test_df.shape)


  return train_df ,test_df

def createsqrtfeatures(train,test,features):
    

  cols = features
  interactionstrain = pd.DataFrame(index=train.index)
  interactionstest = pd.DataFrame(index=test.index)
  
  for col  in cols:   
        newcolname = col + "_sqrt"   
        new_values = np.sqrt(train[col])
        interactionstrain[newcolname] = new_values

  for col  in cols:   
        newcolname = col + "_sqrt"   
        new_values = np.sqrt(test[col])
        interactionstest[newcolname] = new_values


  train_df = train.join(interactionstrain)
  test_df = test.join(interactionstest)

  print(train_df.shape,test_df.shape)


  return train_df ,test_df

# %%
def createmorefeatures(train,test):

# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import log_loss
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import classification_report
from sklearn.metrics import classification_report
    
# Function for comparing different approaches
def score_dataset(X_train, X_valid, y_train, y_valid):
    #model = RandomForestClassifier(random_state=0)
    #model.fit(X_train, y_train)
    from sklearn.tree import DecisionTreeClassifier

    from sklearn.ensemble import BaggingClassifier

    clf1 = DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
                       max_depth=None, max_features=25, max_leaf_nodes=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=8, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, presort='deprecated',
                       random_state=None, splitter='best')

    clf2 = BaggingClassifier(base_estimator=clf1, n_estimators=10, 
                             bootstrap=True,
                             bootstrap_features=False, oob_score=True, warm_start=False,
                             n_jobs=-1, random_state=786, verbose=0)
    clf2.fit(X_train,y_train)

    preds = clf2.predict(X_valid)
    target_names = ['class 0', 'class 1', 'class 2','class 3', 'class 4', 'class 5', 'class 6']
    print(classification_report(y_valid, preds, target_names=target_names,labels= [0,1,2,3,4,5,6]))
    return clf2.score(X_valid,y_valid)

# %%
# X_train, X_valid, y_train, y_valid
#clf1

# %%
X_trainS, X_validS = special(X_train ,X_valid)
# Out:
# /home/ryan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ryan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ryan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ryan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ryan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (95837, 18) (51606, 18)
# /home/ryan/.local/lib/python3.6/site-packages/ipykernel_launcher.py:155: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
X_trainSDr, X_validSDr = dropcol(X_trainS,X_validS)
# Out:
# (95837, 17) (51606, 17)

# %%
X_trainSDrIM, X_validSDrIM = imputer(X_trainSDr,X_validSDr)
# Out:
# (95837, 17) (51606, 17)

# %%
missingcheck(X_trainSDrIM),missingcheck( X_validSDrIM)
# Out:
# (                   Total    %
#  logID                  0  0.0
#  LocationID             0  0.0
#  FacilityID             0  0.0
#  FacilityName           0  0.0
#  Type                   0  0.0
#  Street                 0  0.0
#  City                   0  0.0
#  State                  0  0.0
#  Reason                 0  0.0
#  year                   0  0.0
#  SectionViolations      0  0.0
#  RiskLevel              0  0.0
#  Geo_Loc                0  0.0
#  hour                   0  0.0
#  day                    0  0.0
#  month                  0  0.0
#  LicenseNo              0  0.0,                    Total    %
#  logID                  0  0.0
#  LocationID             0  0.0
#  FacilityID             0  0.0
#  FacilityName           0  0.0
#  Type                   0  0.0
#  Street                 0  0.0
#  City                   0  0.0
#  State                  0  0.0
#  Reason                 0  0.0
#  year                   0  0.0
#  SectionViolations      0  0.0
#  RiskLevel              0  0.0
#  Geo_Loc                0  0.0
#  hour                   0  0.0
#  day                    0  0.0
#  month                  0  0.0
#  LicenseNo              0  0.0)

# %%
X_trainSDrIMinter1,X_validSDrIMinter1 = createIntercations(X_trainSDrIM, X_validSDrIM,cat_features = ['SectionViolations','RiskLevel','Reason'])
# Out:
# Creating features on ['SectionViolations', 'RiskLevel', 'Reason'], with combination 2 for training data /n
# Creating features on ['SectionViolations', 'RiskLevel', 'Reason'], with combination 2 for testing data
# (95837, 20) (51606, 20)

# %%
X_trainSDrIMinter2,X_validSDrIMinter2 = createIntercations(X_trainSDrIMinter1, X_validSDrIMinter1,cat_features = ['State','City','Street','LocationID','Geo_Loc']
)
# Out:
# Creating features on ['State', 'City', 'Street', 'LocationID', 'Geo_Loc'], with combination 2 for training data /n
# Creating features on ['State', 'City', 'Street', 'LocationID', 'Geo_Loc'], with combination 2 for testing data
# (95837, 30) (51606, 30)

# %%
# X_trainSDrIMintertgenc,X_validSDrIMinter2tgenc = targetencoding(X_trainSDrIMinter2,X_validSDrIMinter2,y_train)

# %%
X_trainSDrIMinter2lbl,X_validSDrIMinter2lbl = robustlabelencoder(X_trainSDrIMinter2,X_validSDrIMinter2 )
# Out:
# ['Type', 'Reason', 'SectionViolations_RiskLevel', 'SectionViolations_Reason', 'RiskLevel_Reason', 'State_Street', 'State_LocationID', 'State_Geo_Loc', 'City_Street', 'City_LocationID', 'City_Geo_Loc', 'Street_LocationID', 'Street_Geo_Loc', 'LocationID_Geo_Loc']
# (95837, 30) (51606, 30)

# %%
X_trainSDrIMinter2lblohe,X_validSDrIMinter2lblohe = onhotencoder(X_trainSDrIMinter2lbl,X_validSDrIMinter2lbl)
# Out:
# ['City', 'State', 'RiskLevel', 'State_City']
# (95837, 38) (51606, 38)

# %%
features = X_trainSDrIMinter2lblohe.columns
features
# Out:
# Index(['LicenseNo', 'FacilityID', 'FacilityName', 'Type', 'Street',
#        'LocationID', 'Reason', 'SectionViolations', 'Geo_Loc', 'hour', 'day',
#        'month', 'year', 'logID', 'SectionViolations_RiskLevel',
#        'SectionViolations_Reason', 'RiskLevel_Reason', 'State_Street',
#        'State_LocationID', 'State_Geo_Loc', 'City_Street', 'City_LocationID',
#        'City_Geo_Loc', 'Street_LocationID', 'Street_Geo_Loc',
#        'LocationID_Geo_Loc', 'City_id-11235901', 'City_id-11275913',
#        'State_id_1890134', 'State_id_1890135', 'RiskLevel_High',
#        'RiskLevel_Low', 'RiskLevel_Medium', 'RiskLevel_Uncertain',
#        'State_City_id_1890134_id-11235901',
#        'State_City_id_1890134_id-11275913',
#        'State_City_id_1890135_id-11235901',
#        'State_City_id_1890135_id-11275913'],
#       dtype='object')

# %%
X_trainSDrIMinter2lblohem,X_validSDrIMinter2lblohem = createmeanfestures(X_trainSDrIMinter2lblohe,X_validSDrIMinter2lblohe,features)
# Out:
# (95837, 76) (51606, 76)

# %%
X_trainSDrIMinter2lblohemlog,X_validSDrIMinter2lblohemlog = createlogfestures(X_trainSDrIMinter2lblohem,X_validSDrIMinter2lblohem,features)
# Out:
# (95837, 114) (51606, 114)

# %%
X_trainSDrIMinter2lblohemlogsqrt,X_validSDrIMinter2lblohemlogsqrt = createsqrtfeatures(X_trainSDrIMinter2lblohemlog,X_validSDrIMinter2lblohemlog,features)
# Out:
# (95837, 152) (51606, 152)

# %%
    from sklearn.tree import DecisionTreeClassifier

    from sklearn.ensemble import BaggingClassifier

    clf1 = DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
                       max_depth=None, max_features=25, max_leaf_nodes=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=8, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, presort='deprecated',
                       random_state=None, splitter='best')

    clf2 = BaggingClassifier(base_estimator=clf1, n_estimators=10, 
                             bootstrap=True,
                             bootstrap_features=False, oob_score=True, warm_start=False,
                             n_jobs=-1, random_state=786, verbose=0)
    clf2.fit(X_trainSDrIMinter2lblohemlogsqrt,y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:633: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:638: RuntimeWarning: invalid value encountered in true_divide
#   predictions.sum(axis=1)[:, np.newaxis])

# %%
preds = clf2.predict_proba(X_validSDrIMinter2lblohemlogsqrt)

# %%
clf4=xgb.XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=0.8, gamma=0.5,
              learning_rate=0.1, max_delta_step=0, max_depth=5,
              min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
              nthread=None, objective='multi:softprob', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
              silent=None, subsample=0.6, verbosity=1)

# %%
clf4.fit(X_trainSDrIMinter2lblohemlogsqrt,y_train)

# %%
preds1 = clf4.predict_proba(X_validSDrIMinter2lblohemlogsqrt)

# %%
final_sub = pd.DataFrame(data=np.mean([preds, preds1], axis=0)
                         , columns=submission.columns)

# %%
final_sub
# Out:
#        FACILITY CHANGED      FAIL  FURTHER INSPECTION REQUIRED  \
# 0              0.000457  0.456395                     0.000534
# 1              0.000508  0.001860                     0.001110
# 2              0.000211  0.001105                     0.000733
# 3              0.000237  0.012211                     0.000191
# 4              0.000085  0.000457                     0.000065
# ...                 ...       ...                          ...
# 51601          0.000450  0.002295                     0.005567
# 51602          0.003389  0.001972                     0.002295
# 51603          0.000263  0.855239                     0.000243
# 51604          0.000321  0.132971                     0.000368
# 51605          0.000230  0.007611                     0.002307
#
#        INSPECTION OVERRULED      PASS  PASS(CONDITIONAL)  SHUT-DOWN
# 0                  0.004240  0.003150           0.534884   0.000339
# 1                  0.131928  0.342909           0.001729   0.519955
# 2                  0.014659  0.978447           0.002017   0.002827
# 3                  0.000317  0.833601           0.000767   0.152676
# 4                  0.000577  0.986916           0.011624   0.000275
# ...                     ...       ...                ...        ...
# 51601              0.073109  0.611808           0.004605   0.302168
# 51602              0.074420  0.419795           0.011350   0.486778
# 51603              0.002130  0.005447           0.136429   0.000247
# 51604              0.000766  0.002853           0.862423   0.000298
# 51605              0.006080  0.932041           0.051414   0.000315
#
# [51606 rows x 7 columns]

# %%
# #X_trainSDrIMinter2lblohe.head(2)
# X_trainSDrIMinter2lbloheqq,X_validSDrIMinter2lbloheqq = imputer(X_trainSDrIMintertgenc,X_validSDrIMinter2tgenc)

# %%
X_trainSDrIMinter2lblohem.shape
# Out:
# (95837, 76)

# %%
y_train.shape
# Out:
# (95837,)

# %%
X_validSDrIMinter2lblohem.shape
# Out:
# (51606, 76)

# %%
y_valid.shape
# Out:
# (51606,)

# %%
missingcheck(X_trainSDrIMinter2lbloheqq)
# Out:
#                                     Total    %
# LocationID_Geo_Loc_target               0  0.0
# Street_Geo_Loc_target                   0  0.0
# FacilityID                              0  0.0
# FacilityName                            0  0.0
# Street                                  0  0.0
# LocationID                              0  0.0
# SectionViolations                       0  0.0
# Geo_Loc                                 0  0.0
# hour                                    0  0.0
# day                                     0  0.0
# month                                   0  0.0
# year                                    0  0.0
# logID                                   0  0.0
# Type_target                             0  0.0
# City_target                             0  0.0
# State_target                            0  0.0
# Reason_target                           0  0.0
# RiskLevel_target                        0  0.0
# SectionViolations_RiskLevel_target      0  0.0
# SectionViolations_Reason_target         0  0.0
# RiskLevel_Reason_target                 0  0.0
# State_City_target                       0  0.0
# State_Street_target                     0  0.0
# State_LocationID_target                 0  0.0
# State_Geo_Loc_target                    0  0.0
# City_Street_target                      0  0.0
# City_LocationID_target                  0  0.0
# City_Geo_Loc_target                     0  0.0
# Street_LocationID_target                0  0.0
# LicenseNo                               0  0.0

# %%
X_trainSDrIMinter2lbloheqq.columns
# Out:
# Index(['LicenseNo', 'FacilityID', 'FacilityName', 'Street', 'LocationID',
#        'SectionViolations', 'Geo_Loc', 'hour', 'day', 'month', 'year', 'logID',
#        'Type_target', 'City_target', 'State_target', 'Reason_target',
#        'RiskLevel_target', 'SectionViolations_RiskLevel_target',
#        'SectionViolations_Reason_target', 'RiskLevel_Reason_target',
#        'State_City_target', 'State_Street_target', 'State_LocationID_target',
#        'State_Geo_Loc_target', 'City_Street_target', 'City_LocationID_target',
#        'City_Geo_Loc_target', 'Street_LocationID_target',
#        'Street_Geo_Loc_target', 'LocationID_Geo_Loc_target'],
#       dtype='object')

# %%
X_trainSDrIMinter2lblohemlog.skew()
# Out:
# LicenseNo                                0.186462
# FacilityID                              -0.064033
# FacilityName                            -0.070667
# Type                                    -1.715462
# Street                                   0.042701
#                                            ...
# RiskLevel_Uncertain_log                       NaN
# State_City_id_1890134_id-11235901_log         NaN
# State_City_id_1890134_id-11275913_log         NaN
# State_City_id_1890135_id-11235901_log         NaN
# State_City_id_1890135_id-11275913_log         NaN
# Length: 114, dtype: float64

# %%
score_dataset(X_trainSDrIMinter2lblohemlogsqrt,X_validSDrIMinter2lblohemlogsqrt,y_train,y_valid)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:633: UserWarning: Some inputs do not have OOB scores. This probably means too few estimators were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:638: RuntimeWarning: invalid value encountered in true_divide
#   predictions.sum(axis=1)[:, np.newaxis])
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#      class 0       0.00      0.00      0.00        17
#      class 1       0.80      0.69      0.74     10009
#      class 2       0.49      0.37      0.42       465
#      class 3       0.49      0.21      0.29      1641
#      class 4       0.88      0.94      0.91     27842
#      class 5       0.71      0.75      0.73      7138
#      class 6       0.64      0.65      0.65      4494
#
#     accuracy                           0.81     51606
#    macro avg       0.57      0.52      0.53     51606
# weighted avg       0.80      0.81      0.80     51606
# 0.8105065302484207

# %%
def featureselection(train,y_train):
    from sklearn.linear_model import LogisticRegression
    from sklearn.ensemble import ExtraTreesClassifier
    from sklearn.feature_selection import SelectFromModel
    from lightgbm import LGBMClassifier
    from sklearn.feature_selection import chi2
    from sklearn.preprocessing import MinMaxScaler
    from sklearn.feature_selection import RFE
    from sklearn.feature_selection import SelectKBest

    feature_name = train.columns.tolist()

    
    rf = RandomForestClassifier(n_estimators=100, random_state=7 )
    model_rf = SelectFromModel(rf ,threshold ='1.25*median')
    X_new_rf = model_rf.fit(train,y_train)
    embeded_rf_support = model_rf.get_support()
    embeded_rf_feature = train.loc[:,embeded_rf_support].columns.tolist()
    
    
    lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
            reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)
    model_lgbc = SelectFromModel(lgbc,threshold = '1.25*median')
    X_new_lgbc = model_lgbc.fit(X_trainSDrIMinter2lblohemlogsqrt,y_train)
    lgbc_rf_support = model_lgbc.get_support()
    lgbc_rf_feature = train.loc[:,lgbc_rf_support].columns.tolist()
    
    
    cor_support, cor_feature = cor_selector(train, y_train)
    
    
    X_norm = MinMaxScaler().fit_transform(train)
    chi_selector = SelectKBest(chi2, k=80)
    chi_selector.fit(X_norm, y_train)
    chi_support = chi_selector.get_support()
    chi_feature = train.loc[:,chi_support].columns.tolist()
    
    
    rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10, verbose=5)
    rfe_selector.fit(X_norm, y_train)
    rfe_support = rfe_selector.get_support()
    rfe_feature = train.loc[:,rfe_support].columns.tolist()
    
    
    embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l1",solver = 'liblinear'), '1.25*median')
    embeded_lr_selector.fit(X_norm, y_train)

    embeded_lr_support = embeded_lr_selector.get_support()
    embeded_lr_feature = train.loc[:,embeded_lr_support].columns.tolist()
    
    
    pd.set_option('display.max_rows', None)
    
    feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE':rfe_support, 'Logistics':embeded_lr_support,
                                        'Random Forest':embeded_rf_support, 'LightGBM':lgbc_rf_support})
    
    feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
    feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
    feature_selection_df.index = range(1, len(feature_selection_df)+1)
    feature_selection_df.head(100)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.feature_selection import SelectFromModel
extclf = ExtraTreesClassifier(n_estimators=100, random_state=7)

# Set the regularization parameter C=1
rf = RandomForestClassifier(n_estimators=100, random_state=7 )
model = SelectFromModel(rf ,threshold ='1.25*median')


X_new = model.fit(X_trainSDrIMinter2lblohemlogsqrt,y_train)

# %%
embeded_rf_support = model.get_support()
embeded_rf_feature = X_trainSDrIMinter2lblohemlogsqrt.loc[:,embeded_rf_support].columns.tolist()

# %%
len(embeded_rf_feature)
# Out:
# 75

# %%
from lightgbm import LGBMClassifier

lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
            reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)

model = SelectFromModel(lgbc,threshold = '1.25*median')

X_new = model.fit(X_trainSDrIMinter2lblohemlogsqrt,y_train)

lgbc_rf_support = model.get_support()
lgbc_rf_feature = X_trainSDrIMinter2lblohemlogsqrt.loc[:,lgbc_rf_support].columns.tolist()

# %%
len(lgbc_rf_feature)
# Out:
# 75

# %%
def cor_selector(X, y):
    cor_list = []
    feature_name = X.columns.tolist()

    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-100:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature

# %%
cor_support, cor_feature = cor_selector(X_trainSDrIMinter2lblohemlogsqrt, y_train)
# Out:
# /home/ryan/.local/lib/python3.6/site-packages/numpy/lib/function_base.py:2530: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/ryan/.local/lib/python3.6/site-packages/numpy/lib/function_base.py:2531: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %%
from sklearn.feature_selection import SelectKBest

# %%
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
X_norm = MinMaxScaler().fit_transform(X_trainSDrIMinter2lblohemlogsqrt)
chi_selector = SelectKBest(chi2, k=80)
chi_selector.fit(X_norm, y_train)
# Out:
# SelectKBest(k=80, score_func=<function chi2 at 0x7fc584ca1e18>)

# %%
chi_support = chi_selector.get_support()
chi_feature = X_trainSDrIMinter2lblohemlogsqrt.loc[:,chi_support].columns.tolist()
print(str(len(chi_feature)), 'selected features')
# Out:
# 80 selected features

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10, verbose=5)
rfe_selector.fit(X_norm, y_train)
# Out:
# Fitting estimator with 152 features.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Fitting estimator with 142 features.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Fitting estimator with 132 features.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Fitting estimator with 122 features.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Fitting estimator with 112 features.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Fitting estimator with 102 features.
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# RFE(estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                  fit_intercept=True, intercept_scaling=1,
#                                  l1_ratio=None, max_iter=100,
#                                  multi_class='auto', n_jobs=None, penalty='l2',
#                                  random_state=None, solver='lbfgs', tol=0.0001,
#                                  verbose=0, warm_start=False),
#     n_features_to_select=100, step=10, verbose=5)

# %%
rfe_support = rfe_selector.get_support()
rfe_feature = X_trainSDrIMinter2lblohemlogsqrt.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# 100 selected features

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression

embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l1",solver = 'liblinear'), '1.25*median')
embeded_lr_selector.fit(X_norm, y_train)

embeded_lr_support = embeded_lr_selector.get_support()
embeded_lr_feature = X_trainSDrIMinter2lblohemlogsqrt.loc[:,embeded_lr_support].columns.tolist()
print(str(len(embeded_lr_feature)), 'selected features')
# Out:
# 67 selected features

# %%
feature_name = X_trainSDrIMinter2lblohemlogsqrt.columns.to_list()

# %%
pd.set_option('display.max_rows', None)
# put all selection together
feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE':rfe_support, 'Logistics':embeded_lr_support,
                                    'Random Forest':embeded_rf_support, 'LightGBM':lgbc_rf_support})
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)
feature_selection_df
# Out:
#                                     Feature  Pearson  Chi-2    RFE  Logistics  \
# 1                                 year_sqrt     True   True   True       True
# 2                                  year_log     True   True   True       True
# 3                                      year     True   True   True       True
# 4                                 month_log     True   True   True       True
# 5                                     month     True   True   True       True
# 6                                   day_log     True   True   True       True
# 7                                       day     True   True   True       True
# 8                                      Type     True   True   True       True
# 9                          State_LocationID     True   True   True       True
# 10                       State_Geo_Loc_sqrt     True   True   True       True
# 11                            State_Geo_Loc     True   True   True       True
# 12                   SectionViolations_sqrt     True   True   True       True
# 13                    SectionViolations_log     True   True   True       True
# 14         SectionViolations_RiskLevel_sqrt     True   True   True       True
# 15          SectionViolations_RiskLevel_log     True   True   True       True
# 16              SectionViolations_RiskLevel     True   True   True       True
# 17            SectionViolations_Reason_sqrt     True   True   True       True
# 18             SectionViolations_Reason_log     True   True   True       True
# 19                 SectionViolations_Reason     True   True   True       True
# 20                        SectionViolations     True   True   True       True
# 21                    RiskLevel_Reason_sqrt     True   True   True       True
# 22                     RiskLevel_Reason_log     True   True   True       True
# 23                         RiskLevel_Reason     True   True   True       True
# 24                              Reason_sqrt     True   True   True       True
# 25                               Reason_log     True   True   True       True
# 26                                   Reason     True   True   True       True
# 27                  LocationID_Geo_Loc_sqrt     True   True   True       True
# 28                   LocationID_Geo_Loc_log     True   True   True       True
# 29                       LocationID_Geo_Loc     True   True   True       True
# 30                           LicenseNo_sqrt     True   True   True       True
# 31                            LicenseNo_log     True   True   True       True
# 32                                LicenseNo     True   True   True       True
# 33                             Geo_Loc_sqrt     True   True   True       True
# 34                                  Geo_Loc     True   True   True       True
# 35                               FacilityID     True   True   True       True
# 36                          City_LocationID     True   True   True       True
# 37                        City_Geo_Loc_sqrt     True   True   True       True
# 38                         City_Geo_Loc_log     True   True   True       True
# 39                               month_sqrt     True   True   True      False
# 40                                 day_sqrt     True   True   True      False
# 41                                Type_sqrt     True   True   True      False
# 42                                 Type_log     True  False   True       True
# 43                              Street_sqrt     True   True   True      False
# 44                               Street_log     True  False   True       True
# 45                        Street_LocationID     True   True   True      False
# 46                           Street_Geo_Loc     True   True   True      False
# 47                                   Street     True   True   True      False
# 48                             State_Street     True   True   True      False
# 49                    State_LocationID_sqrt     True  False   True       True
# 50                     State_LocationID_log     True  False   True       True
# 51                        State_Geo_Loc_log     True   True   True      False
# 52                          LocationID_sqrt     True  False   True       True
# 53                           LocationID_log     True  False   True       True
# 54                               LocationID     True  False   True       True
# 55                              Geo_Loc_log     True  False   True       True
# 56                        FacilityName_sqrt     True  False   True       True
# 57                             FacilityName     True   True   True      False
# 58                          FacilityID_sqrt     True   True   True      False
# 59                           FacilityID_log     True  False   True       True
# 60                          City_Street_log     True  False   True       True
# 61                              City_Street     True   True   True      False
# 62                     City_LocationID_sqrt     True   True   True      False
# 63                      City_LocationID_log     True   True   True      False
# 64                             City_Geo_Loc     True   True   True      False
# 65                               logID_sqrt     True  False   True      False
# 66                                logID_log     True  False   True      False
# 67                                    logID     True  False   True      False
# 68                   Street_LocationID_sqrt     True  False   True      False
# 69                    Street_LocationID_log     True  False   True      False
# 70                      Street_Geo_Loc_sqrt     True  False   True      False
# 71                       Street_Geo_Loc_log     True  False   True      False
# 72                        State_Street_sqrt     True  False   True      False
# 73                         State_Street_log     True  False   True      False
# 74                     RiskLevel_Medium_log     True   True   True       True
# 75                         RiskLevel_Medium     True   True   True       True
# 76                      RiskLevel_High_sqrt     True   True   True       True
# 77                         FacilityName_log     True  False   True      False
# 78                         City_Street_sqrt     True  False   True      False
# 79                    State_id_1890135_sqrt     True   True  False       True
# 80                     State_id_1890135_log     True   True  False       True
# 81                         State_id_1890135     True   True  False       True
# 82                    State_id_1890134_sqrt     True  False   True       True
# 83                     State_id_1890134_log     True  False   True       True
# 84                         State_id_1890134     True  False   True       True
# 85   State_City_id_1890134_id-11275913_sqrt     True   True   True      False
# 86    State_City_id_1890134_id-11275913_log     True   True   True      False
# 87        State_City_id_1890134_id-11275913     True   True   True      False
# 88    State_City_id_1890134_id-11235901_log     True  False   True       True
# 89                 RiskLevel_Uncertain_sqrt     True   True  False       True
# 90                      RiskLevel_Uncertain     True   True   True      False
# 91                    RiskLevel_Medium_sqrt     True   True   True      False
# 92                       RiskLevel_Low_sqrt     True   True   True      False
# 93                        RiskLevel_Low_log     True   True   True      False
# 94                            RiskLevel_Low     True   True   True      False
# 95                       RiskLevel_High_log     True   True   True      False
# 96                           RiskLevel_High     True   True   True      False
# 97                    City_id-11275913_sqrt    False   True   True       True
# 98                     City_id-11275913_log    False   True   True       True
# 99                         City_id-11275913    False   True   True       True
# 100  State_City_id_1890135_id-11275913_sqrt     True   True  False      False
# 101   State_City_id_1890135_id-11275913_log     True   True  False      False
# 102       State_City_id_1890135_id-11275913     True   True  False      False
# 103  State_City_id_1890134_id-11235901_sqrt    False  False   True       True
# 104                 RiskLevel_Uncertain_log     True   True  False      False
# 105                   City_id-11235901_sqrt    False  False   True       True
# 106                    City_id-11235901_log    False  False   True       True
# 107                        City_id-11235901    False  False   True       True
# 108  State_City_id_1890135_id-11235901_sqrt    False   True  False      False
# 109   State_City_id_1890135_id-11235901_log    False   True  False      False
# 110       State_City_id_1890135_id-11235901    False   True  False      False
# 111       State_City_id_1890134_id-11235901    False  False   True      False
# 112                               year_mean    False  False  False      False
# 113                              month_mean    False  False  False      False
# 114                              logID_mean    False  False  False      False
# 115                               hour_sqrt    False  False  False      False
# 116                               hour_mean    False  False  False      False
# 117                                hour_log    False  False  False      False
# 118                                    hour    False  False  False      False
# 119                                day_mean    False  False  False      False
# 120                               Type_mean    False  False  False      False
# 121                             Street_mean    False  False  False      False
# 122                  Street_LocationID_mean    False  False  False      False
# 123                     Street_Geo_Loc_mean    False  False  False      False
# 124                   State_id_1890135_mean    False  False  False      False
# 125                   State_id_1890134_mean    False  False  False      False
# 126                       State_Street_mean    False  False  False      False
# 127                   State_LocationID_mean    False  False  False      False
# 128                      State_Geo_Loc_mean    False  False  False      False
# 129  State_City_id_1890135_id-11275913_mean    False  False  False      False
# 130  State_City_id_1890135_id-11235901_mean    False  False  False      False
# 131  State_City_id_1890134_id-11275913_mean    False  False  False      False
# 132  State_City_id_1890134_id-11235901_mean    False  False  False      False
# 133                  SectionViolations_mean    False  False  False      False
# 134        SectionViolations_RiskLevel_mean    False  False  False      False
# 135           SectionViolations_Reason_mean    False  False  False      False
# 136                RiskLevel_Uncertain_mean    False  False  False      False
# 137                   RiskLevel_Reason_mean    False  False  False      False
# 138                   RiskLevel_Medium_mean    False  False  False      False
# 139                      RiskLevel_Low_mean    False  False  False      False
# 140                     RiskLevel_High_mean    False  False  False      False
# 141                             Reason_mean    False  False  False      False
# 142                         LocationID_mean    False  False  False      False
# 143                 LocationID_Geo_Loc_mean    False  False  False      False
# 144                          LicenseNo_mean    False  False  False      False
# 145                            Geo_Loc_mean    False  False  False      False
# 146                       FacilityName_mean    False  False  False      False
# 147                         FacilityID_mean    False  False  False      False
# 148                   City_id-11275913_mean    False  False  False      False
# 149                   City_id-11235901_mean    False  False  False      False
# 150                        City_Street_mean    False  False  False      False
# 151                    City_LocationID_mean    False  False  False      False
# 152                       City_Geo_Loc_mean    False  False  False      False
#
#      Random Forest  LightGBM  Total
# 1             True      True      6
# 2             True      True      6
# 3             True      True      6
# 4             True      True      6
# 5             True      True      6
# 6             True      True      6
# 7             True      True      6
# 8             True      True      6
# 9             True      True      6
# 10            True      True      6
# 11            True      True      6
# 12            True      True      6
# 13            True      True      6
# 14            True      True      6
# 15            True      True      6
# 16            True      True      6
# 17            True      True      6
# 18            True      True      6
# 19            True      True      6
# 20            True      True      6
# 21            True      True      6
# 22            True      True      6
# 23            True      True      6
# 24            True      True      6
# 25            True      True      6
# 26            True      True      6
# 27            True      True      6
# 28            True      True      6
# 29            True      True      6
# 30            True      True      6
# 31            True      True      6
# 32            True      True      6
# 33            True      True      6
# 34            True      True      6
# 35            True      True      6
# 36            True      True      6
# 37            True      True      6
# 38            True      True      6
# 39            True      True      5
# 40            True      True      5
# 41            True      True      5
# 42            True      True      5
# 43            True      True      5
# 44            True      True      5
# 45            True      True      5
# 46            True      True      5
# 47            True      True      5
# 48            True      True      5
# 49            True      True      5
# 50            True      True      5
# 51            True      True      5
# 52            True      True      5
# 53            True      True      5
# 54            True      True      5
# 55            True      True      5
# 56            True      True      5
# 57            True      True      5
# 58            True      True      5
# 59            True      True      5
# 60            True      True      5
# 61            True      True      5
# 62            True      True      5
# 63            True      True      5
# 64            True      True      5
# 65            True      True      4
# 66            True      True      4
# 67            True      True      4
# 68            True      True      4
# 69            True      True      4
# 70            True      True      4
# 71            True      True      4
# 72            True      True      4
# 73            True      True      4
# 74           False     False      4
# 75           False     False      4
# 76           False     False      4
# 77            True      True      4
# 78            True      True      4
# 79           False     False      3
# 80           False     False      3
# 81           False     False      3
# 82           False     False      3
# 83           False     False      3
# 84           False     False      3
# 85           False     False      3
# 86           False     False      3
# 87           False     False      3
# 88           False     False      3
# 89           False     False      3
# 90           False     False      3
# 91           False     False      3
# 92           False     False      3
# 93           False     False      3
# 94           False     False      3
# 95           False     False      3
# 96           False     False      3
# 97           False     False      3
# 98           False     False      3
# 99           False     False      3
# 100          False     False      2
# 101          False     False      2
# 102          False     False      2
# 103          False     False      2
# 104          False     False      2
# 105          False     False      2
# 106          False     False      2
# 107          False     False      2
# 108          False     False      1
# 109          False     False      1
# 110          False     False      1
# 111          False     False      1
# 112          False     False      0
# 113          False     False      0
# 114          False     False      0
# 115          False     False      0
# 116          False     False      0
# 117          False     False      0
# 118          False     False      0
# 119          False     False      0
# 120          False     False      0
# 121          False     False      0
# 122          False     False      0
# 123          False     False      0
# 124          False     False      0
# 125          False     False      0
# 126          False     False      0
# 127          False     False      0
# 128          False     False      0
# 129          False     False      0
# 130          False     False      0
# 131          False     False      0
# 132          False     False      0
# 133          False     False      0
# 134          False     False      0
# 135          False     False      0
# 136          False     False      0
# 137          False     False      0
# 138          False     False      0
# 139          False     False      0
# 140          False     False      0
# 141          False     False      0
# 142          False     False      0
# 143          False     False      0
# 144          False     False      0
# 145          False     False      0
# 146          False     False      0
# 147          False     False      0
# 148          False     False      0
# 149          False     False      0
# 150          False     False      0
# 151          False     False      0
# 152          False     False      0
